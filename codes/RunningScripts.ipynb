# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !pip install tensorflow==1.12.0
# !pip install -q keras==2.2.4
# !pip install trackpy
# !pip install pims
# Out:
# ...
#      |████████████████████████████████| 83.1MB 64kB/s
# ...
#      |████████████████████████████████| 3.1MB 40.3MB/s
# ...
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# ...

# %%
# %cd drive/My\ Drive/
# %cd LinuxBackUp/keras-yolo3-beiyong/keras-yolo3/
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/LinuxBackUp/keras-yolo3-beiyong/keras-yolo3

# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive/My Drive/LinuxBackUp/keras-yolo3-beiyong/keras-yolo3

# %%
# !python3 yolo_draw_text_boxv2.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python drawBoxes.py
# Out:
# 10:27
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100

# %%
# !python3 pureTrackpy.py

# %%
# !python3 trackpyOnEuler.py
# Out:
# Exception ignored in: <object repr() failed>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/pims/image_sequence.py", line 94, in __del__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/pims/image_sequence.py", line 89, in close
#     if self._is_zipfile:
# AttributeError: 'ImageSequence' object has no attribute '_is_zipfile'
# Traceback (most recent call last):
#   File "trackpyOnEuler.py", line 14, in <module>
#     aa = pims.ImageSequence('./frame_crop/*.jpg', as_grey=True)
# TypeError: __init__() got an unexpected keyword argument 'as_grey'

# %%
# !python3 yolo_force_Size.py

# %%
# !python3 trackpyDC.py
# Out:
# trackpy.linking.linking.link_iter:  Frame 1: 24 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 2: 23 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 3: 25 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 4: 24 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 5: 27 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 6: 26 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 7: 26 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 8: 28 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 9: 29 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 10: 26 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 11: 23 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 12: 23 trajectories present.
# trackpy.linking.linking.link_iter:  Frame 13: 22 trajectories present.
# ...

# %%
# !python3 YOLOIOU_output.py

# %%
# %cd ..
# %cd keras-yolo3/
# Out:
# /content/drive/My Drive/LinuxBackUp/keras-yolo3-beiyong
# /content/drive/My Drive/LinuxBackUp/keras-yolo3-beiyong/keras-yolo3

# %%
cd watershed/
# Out:
# /content/drive/My Drive/LinuxBackUp/keras-yolo3-beiyong/keras-yolo3/watershed

# %%
# !python size_center_dongxia.py
# Out:
# 9:31
# Traceback (most recent call last):
#   File "size_center_dongxia.py", line 65, in <module>
#     cv2.imwrite('./crop_set2_final/'+str(i)+'/'+str(l)+'.jpg', crop_im2)
# cv2.error: OpenCV(4.1.2) /io/opencv/modules/imgcodecs/src/loadsave.cpp:715: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
# %mkdir {0..1175}

# %%
# !python drawBoxes51.py
# Out:
# 11:00
# 296.4151382
# 2
# 297.7590656000001
# 3
# 296.1499996
# 4
# 296.8148785
# 5
# 294.5
# 6
# 297.3538456
# 7
# 295.5
# 8
# 296.0
# 9
# 296.0
# 10
# 294.0
# 11
# 293.0
# 12
# 294.0
# 13
# 295.0
# 14
# 295.2758636000001
# 15
# 296.3970585
# 16
# 294.5
# 17
# 296.0890427
# 18
# 295.0
# 19
# 296.0
# 20
# 296.7153854
# 21
# 295.5
# 22
# 295.88989260000005
# 23
# 294.5
# 24
# 295.5
# 25
# 295.0
# 26
# 296.6027031000001
# 27
# 296.7875633
# 28
# 296.817646
# 29
# 295.5
# 30
# 295.7500019
# 31
# 294.5
# 32
# 295.0
# 33
# 294.5
# 34
# 295.0
# 35
# 295.7846146
# 36
# 294.5
# 37
# 294.0
# 38
# 293.5
# 39
# 295.4719086
# 40
# 296.4055786
# 41
# 294.0
# 42
# 295.5
# 43
# 295.684
# 44
# 294.5
# 45
# 294.5
# 46
# 296.3724861
# 47
# 295.5
# 48
# 295.6153831000001
# 49
# 296.0405388000001
# 50
# Traceback (most recent call last):
#   File "drawBoxes51.py", line 42, in <module>
# ...

# %%
import cv2
from os import walk, getcwd
from PIL import Image
import math
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
#from skimage import data
linewidth = 5
yume=10
# Mag=1340/416
# MagY=952/416
#with open("./wholeVideo/positionforeachDefect/87.txt") as filehandle:
print("11:00")
with open("51.txt") as filehandle:
    images= filehandle.readline()
    imagelist= images.split("),")
    images=[]
    for image in imagelist:
        images.append(image.replace("(", "").replace("[","").strip().split(","))
    listToOpen=list()
    for item in images:
        listToOpen.append((item[0], (item[1], item[2])))
    for item in listToOpen:
        im = mpimg.imread("./frame_crop/Frame"+item[0]+".jpg")

        #resized_image = cv2.resize(im, (1340, 952))
        fig, ax = plt.subplots(figsize=(50, 50))
        
        Xmin= float(item[1][0])-yume
        print(Xmin)
        Xmax= float(item[1][0])+yume
        width=Xmax-Xmin
        height=Ymax-Ymin
        width=2*yume
        height=2*yume
        rect = patches.Rectangle((Xmin, Ymin), width, height, linewidth=linewidth, edgecolor='deepskyblue', facecolor = 'none')
        ax.add_patch(rect)
        ax.imshow(im)
        
        if(int(item[0])%50==0):
            print(item[0])
            fig.savefig("./trajectoryImagesPlotted51/"+item[0]+".jpg",format='jpeg',dpi=300, bbox_inches="tight",pad_inches=0.2)
        plt.close()
# Out:
# 11:00
# 1059.800459
# 1060.984454
# 1059.549999
# 1059.5346029999996
# 1061.5
# 1060.130769
# 1059.5
# 1061.0
# 1062.0
# 1061.0
# 1061.0
# 1062.5
# 1060.0
# 1059.310345
# 1059.838236
# 1059.5
# 1059.095891
# 1061.0
# 1062.0
# 1060.223075
# 1062.0
# 1059.893502
# 1061.5
# 1061.5
# 1061.0
# 1060.983784
# 1059.792746
# 1059.929413
# 1060.5
# 1059.75
# 1060.5
# 1061.0
# 1060.5
# 1061.5
# 1059.376923
# 1061.5
# 1061.0
# 1060.0
# 1061.455056
# 1059.403435
# 1062.0
# 1062.0
# 1060.011999
# 1062.5
# 1062.0
# 1059.610739
# 1060.5
# 1059.576923
# 1059.743243
# 50
# 1060.0
# 1058.481957
# 1057.829508
# 1058.0
# 1058.5
# 1058.800429
# 1059.0
# 1058.733946
# 1058.599999
# 1058.799999
# 1058.84083
# 1060.5
# 1058.287198
# 1058.244261
# 1058.7
# 1060.0
# 1060.0
# 1058.426606
# 1059.200001
# 1059.400001
# 1059.779413
# 1058.753426
# 1058.332862
# 1059.630769
# 1059.538462
# 1058.988533
# 1058.578766
# 1060.0
# 1059.667431
# 1060.07353
# 1059.955883
# 1059.200361
# 1060.391891
# 1059.402685
# ...
